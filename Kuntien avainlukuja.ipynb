# %%
import pandas as pd

# %%
df=pd.read_excel('kunnat.xlsx', sheetname='Kuntien avainluvut')
df.head()
# Out:
#        Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 0       Akaa                   88.5           16769
# 1   Alajärvi                   60.7            9831
# 2  Alavieska                   52.6            2610
# 3     Alavus                   59.5           11713
# 4   Asikkala                   64.4            8248
#
#    Väkiluvun muutos edellisestä vuodesta, %, 2017  \
# 0                                            -0.9
# 1                                            -0.7
# 2                                            -1.1
# 3                                            -1.6
# 4                                            -0.9
#
#    Alle 15-vuotiaiden osuus väestöstä, %, 2017  \
# 0                                         18.0
# 1                                         17.7
# 2                                         19.6
# 3                                         17.0
# 4                                         14.2
#
#    15-64 -vuotiaiden osuus väestöstä, %, 2017  \
# 0                                        59.8
# 1                                        55.7
# 2                                        57.3
# 3                                        56.3
# 4                                        54.7
#
#    Yli 64-vuotiaiden osuus väestöstä, %, 2017  \
# 0                                        22.2
# 1                                        26.6
# 2                                        23.1
# 3                                        26.6
# 4                                        31.1
#
#    Ruotsinkielisten osuus väestöstä, %, 2017  \
# 0                                        0.2
# 1                                        0.1
# 2                                        0.2
# 3                                        0.1
# 4                                        0.2
#
#    Ulkomaan kansalaisten osuus väestöstä, %, 2017  \
# 0                                             1.6
# 1                                             1.9
# 2                                             0.6
# 3                                             1.1
# 4                                             1.6
#
#    Syntyneiden enemmyys, henkilöä, 2017  \
# 0                                   -47
# 1                                   -19
# 2                                    -5
# 3                                   -42
# 4                                   -51
#
#                                           ...                                          \
# 0                                         ...
# 1                                         ...
# 2                                         ...
# 3                                         ...
# 4                                         ...
#
#    Taloudellinen huoltosuhde, 2016  \
# 0                            154.2
# 1                            187.7
# 2                            169.3
# 3                            172.1
# 4                            171.7
#
#    Alueella olevien työpaikkojen lukumäärä, 2016  \
# 0                                           4512
# 1                                           3330
# 2                                            741
# 3                                           4355
# 4                                           2318
#
#    Alkutuotannon työpaikkojen osuus, %, 2016  \
# 0                                        3.3
# 1                                       11.6
# 2                                       24.4
# 3                                        9.9
# 4                                        9.4
#
#    Jalostuksen työpaikkojen osuus, %, 2016  \
# 0                                     35.6
# 1                                     26.4
# 2                                     21.6
# 3                                     23.3
# 4                                     27.4
#
#    Palvelujen työpaikkojen osuus, %, 2016  Vuosikate, euroa/asukas, 2017  \
# 0                                    59.5                          370.2
# 1                                    59.9                          674.0
# 2                                    52.0                          276.2
# 3                                    65.6                          466.4
# 4                                    60.8                          577.5
#
#    Lainakanta, euroa/asukas, 2017  Konsernin lainakanta, euroa/asukas, 2017  \
# 0                          3139.1                                    3927.7
# 1                          2152.1                                    4235.1
# 2                          2988.9                                    3182.4
# 3                          3307.6                                    6004.2
# 4                          1453.7                                    3014.4
#
#    Opetus- ja kulttuuritoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017  \
# 0                                             1579.9
# 1                                             2152.6
# 2                                             1837.5
# 3                                             1780.8
# 4                                             1607.9
#
#    Sosiaali- ja terveystoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017
# 0                                             3231.2
# 1                                             3579.3
# 2                                             3995.8
# 3                                             3886.5
# 4                                             3476.6
#
# [5 rows x 32 columns]

# %%
df.shape
# Out:
# (311, 32)

# %%
df.columns
# Out:
# Index(['Kunta', 'Taajama-aste, %, 2017', 'Väkiluku, 2017',
#        'Väkiluvun muutos edellisestä vuodesta, %, 2017',
#        'Alle 15-vuotiaiden osuus väestöstä, %, 2017',
#        '15-64 -vuotiaiden osuus väestöstä, %, 2017',
#        'Yli 64-vuotiaiden osuus väestöstä, %, 2017',
#        'Ruotsinkielisten osuus väestöstä, %, 2017',
#        'Ulkomaan kansalaisten osuus väestöstä, %, 2017',
#        'Syntyneiden enemmyys, henkilöä, 2017',
#        'Kuntien välinen muuttovoitto/-tappio, henkilöä, 2017',
#        'Perheiden lukumäärä, 2017', 'Asuntokuntien lukumäärä, 2017',
#        'Rivi- ja pientaloissa asuvien asuntokuntien osuus, %, 2017',
#        'Vuokra-asunnoissa asuvien asuntokuntien osuus, %, 2017',
#        'Vähintään toisen asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
#        'Korkea-asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
#        'Alueella asuvan työllisen työvoiman määrä, 2016',
#        'Työllisyysaste, %, 2016',
#        'Asuinkunnassaan työssäkäyvien osuus, %, 2016',
#        'Työttömien osuus työvoimasta, %, 2016',
#        'Eläkeläisten osuus väestöstä, %, 2016',
#        'Taloudellinen huoltosuhde, 2016',
#        'Alueella olevien työpaikkojen lukumäärä, 2016',
#        'Alkutuotannon työpaikkojen osuus, %, 2016',
#        'Jalostuksen työpaikkojen osuus, %, 2016',
#        'Palvelujen työpaikkojen osuus, %, 2016',
#        'Vuosikate, euroa/asukas, 2017', 'Lainakanta, euroa/asukas, 2017',
#        'Konsernin lainakanta, euroa/asukas, 2017',
#        'Opetus- ja kulttuuritoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017',
#        'Sosiaali- ja terveystoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017'],
#       dtype='object')

# %%
df.count()
# Out:
# Kunta                                                                                     311
# Taajama-aste, %, 2017                                                                     311
# Väkiluku, 2017                                                                            311
# Väkiluvun muutos edellisestä vuodesta, %, 2017                                            311
# Alle 15-vuotiaiden osuus väestöstä, %, 2017                                               311
# 15-64 -vuotiaiden osuus väestöstä, %, 2017                                                311
# Yli 64-vuotiaiden osuus väestöstä, %, 2017                                                311
# Ruotsinkielisten osuus väestöstä, %, 2017                                                 311
# Ulkomaan kansalaisten osuus väestöstä, %, 2017                                            311
# Syntyneiden enemmyys, henkilöä, 2017                                                      311
# Kuntien välinen muuttovoitto/-tappio, henkilöä, 2017                                      311
# Perheiden lukumäärä, 2017                                                                 311
# Asuntokuntien lukumäärä, 2017                                                             311
# Rivi- ja pientaloissa asuvien asuntokuntien osuus, %, 2017                                311
# Vuokra-asunnoissa asuvien asuntokuntien osuus, %, 2017                                    311
# Vähintään toisen asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017    311
# Korkea-asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017              311
# Alueella asuvan työllisen työvoiman määrä, 2016                                           311
# Työllisyysaste, %, 2016                                                                   311
# Asuinkunnassaan työssäkäyvien osuus, %, 2016                                              311
# Työttömien osuus työvoimasta, %, 2016                                                     311
# Eläkeläisten osuus väestöstä, %, 2016                                                     311
# Taloudellinen huoltosuhde, 2016                                                           311
# Alueella olevien työpaikkojen lukumäärä, 2016                                             311
# Alkutuotannon työpaikkojen osuus, %, 2016                                                 311
# Jalostuksen työpaikkojen osuus, %, 2016                                                   311
# Palvelujen työpaikkojen osuus, %, 2016                                                    311
# Vuosikate, euroa/asukas, 2017                                                             311
# Lainakanta, euroa/asukas, 2017                                                            311
# Konsernin lainakanta, euroa/asukas, 2017                                                  311
# Opetus- ja kulttuuritoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017        311
# Sosiaali- ja terveystoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017        311
# dtype: int64

# %%
df[df['Väkiluku, 2017']>100000]
# Out:
#          Kunta  Taajama-aste, %, 2017  Väkiluku, 2017  \
# 11       Espoo                   99.5          279044
# 33    Helsinki                  100.0          643272
# 63   Jyväskylä                   94.7          140188
# 114     Kuopio                   85.7          118209
# 123      Lahti                   97.4          119573
# 180       Oulu                   96.4          201810
# 268    Tampere                   98.6          231853
# 276      Turku                   99.0          189669
# 291     Vantaa                   99.7          223027
#
#      Väkiluvun muutos edellisestä vuodesta, %, 2017  \
# 11                                              1.6
# 33                                              1.3
# 63                                              1.0
# 114                                             0.4
# 123                                             0.1
# 180                                             0.6
# 268                                             1.6
# 276                                             1.1
# 291                                             1.7
#
#      Alle 15-vuotiaiden osuus väestöstä, %, 2017  \
# 11                                          19.4
# 33                                          14.3
# 63                                          15.9
# 114                                         15.0
# 123                                         14.7
# 180                                         18.8
# 268                                         13.7
# 276                                         12.9
# 291                                         17.8
#
#      15-64 -vuotiaiden osuus väestöstä, %, 2017  \
# 11                                         66.2
# 33                                         68.9
# 63                                         66.4
# 114                                        64.6
# 123                                        61.8
# 180                                        65.9
# 268                                        67.5
# 276                                        66.7
# 291                                        67.0
#
#      Yli 64-vuotiaiden osuus väestöstä, %, 2017  \
# 11                                         14.5
# 33                                         16.8
# 63                                         17.7
# 114                                        20.4
# 123                                        23.5
# 180                                        15.3
# 268                                        18.8
# 276                                        20.5
# 291                                        15.2
#
#      Ruotsinkielisten osuus väestöstä, %, 2017  \
# 11                                         7.2
# 33                                         5.7
# 63                                         0.2
# 114                                        0.1
# 123                                        0.4
# 180                                        0.2
# 268                                        0.5
# 276                                        5.4
# 291                                        2.5
#
#      Ulkomaan kansalaisten osuus väestöstä, %, 2017  \
# 11                                             10.5
# 33                                              9.5
# 63                                              3.3
# 114                                             2.5
# 123                                             4.3
# 180                                             2.9
# 268                                             4.6
# 276                                             6.5
# 291                                            11.2
#
#      Syntyneiden enemmyys, henkilöä, 2017  \
# 11                                   1649
# 33                                   1524
# 63                                    321
# 114                                   -55
# 123                                  -181
# 180                                   944
# 268                                   376
# 276                                   -10
# 291                                  1149
#
#                                             ...                                          \
# 11                                          ...
# 33                                          ...
# 63                                          ...
# 114                                         ...
# 123                                         ...
# 180                                         ...
# 268                                         ...
# 276                                         ...
# 291                                         ...
#
#      Taloudellinen huoltosuhde, 2016  \
# 11                             115.0
# 33                             111.4
# 63                             143.5
# 114                            142.4
# 123                            155.7
# 180                            145.9
# 268                            138.2
# 276                            139.9
# 291                            113.1
#
#      Alueella olevien työpaikkojen lukumäärä, 2016  \
# 11                                          117007
# 33                                          388005
# 63                                           60992
# 114                                          50877
# 123                                          50483
# 180                                          85288
# 268                                         116748
# 276                                          97273
# 291                                         110784
#
#      Alkutuotannon työpaikkojen osuus, %, 2016  \
# 11                                         0.1
# 33                                         0.1
# 63                                         0.7
# 114                                        2.9
# 123                                        0.5
# 180                                        0.7
# 268                                        0.2
# 276                                        0.4
# 291                                        0.3
#
#      Jalostuksen työpaikkojen osuus, %, 2016  \
# 11                                      15.8
# 33                                      10.1
# 63                                      17.7
# 114                                     13.9
# 123                                     24.7
# 180                                     18.9
# 268                                     18.6
# 276                                     16.2
# 291                                     21.5
#
#      Palvelujen työpaikkojen osuus, %, 2016  Vuosikate, euroa/asukas, 2017  \
# 11                                     82.9                          827.6
# 33                                     88.9                         1302.6
# 63                                     80.5                          478.6
# 114                                    82.1                          486.6
# 123                                    73.8                          507.5
# 180                                    79.4                          590.5
# 268                                    80.3                          367.1
# 276                                    82.4                          206.0
# 291                                    77.4                          735.4
#
#      Lainakanta, euroa/asukas, 2017  Konsernin lainakanta, euroa/asukas, 2017  \
# 11                           2887.0                                   12290.8
# 33                           1874.7                                    7749.1
# 63                           2609.7                                    7386.3
# 114                          2790.0                                    8013.1
# 123                          6314.3                                    9182.9
# 180                          3134.6                                    4004.1
# 268                          2276.2                                    6273.9
# 276                          3991.5                                    7296.5
# 291                          4517.0                                    8836.9
#
#      Opetus- ja kulttuuritoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017  \
# 11                                              2384.0
# 33                                              1924.7
# 63                                              1711.7
# 114                                             1894.6
# 123                                             1761.5
# 180                                             1941.7
# 268                                             2009.8
# 276                                             1880.1
# 291                                             1942.2
#
#      Sosiaali- ja terveystoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017
# 11                                              2574.2
# 33                                              2954.5
# 63                                              2905.6
# 114                                             3418.1
# 123                                             3110.6
# 180                                             2964.4
# 268                                             3245.6
# 276                                             3284.9
# 291                                             2661.7
#
# [9 rows x 32 columns]

# %%
#nimenvaihto
df.columns=['Kunta', 'Taajama-aste, %, 2017', 'Väkiluku, 2017',
       'Väkiluvun muutos edellisestä vuodesta, %, 2017',
       'Alle 15-vuotiaiden osuus väestöstä, %, 2017',
       '15-64 -vuotiaiden osuus väestöstä, %, 2017',
       'Yli 64-vuotiaiden osuus väestöstä, %, 2017',
       'Ruotsinkielisten osuus väestöstä, %, 2017',
       'Ulkomaan kansalaisten osuus väestöstä, %, 2017',
       'Syntyneiden enemmyys, henkilöä, 2017',
       'Kuntien välinen muuttovoitto/-tappio, henkilöä, 2017',
       'Perheiden lukumäärä, 2017', 'Asuntokuntien lukumäärä, 2017',
       'Rivi- ja pientaloissa asuvien asuntokuntien osuus, %, 2017',
       'Vuokra-asunnoissa asuvien asuntokuntien osuus, %, 2017',
       'Vähintään toisen asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
       'Korkea-asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
       'Alueella asuvan työllisen työvoiman määrä, 2016',
       'Työllisyysaste, %, 2016',
       'Asuinkunnassaan työssäkäyvien osuus, %, 2016',
       'Työttömien osuus työvoimasta, %, 2016',
       'Eläkeläisten osuus väestöstä, %, 2016',
       'Taloudellinen huoltosuhde, 2016',
       'Alueella olevien työpaikkojen lukumäärä, 2016',
       'Alkutuotannon työpaikkojen osuus, %, 2016',
       'Jalostuksen työpaikkojen osuus, %, 2016',
       'Palvelujen työpaikkojen osuus, %, 2016',
       'Vuosikate, euroa/asukas, 2017', 'Lainakanta, euroa/asukas, 2017',
       'Konsernin lainakanta, euroa/asukas, 2017',
       'Opetus- ja kulttuuritoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017',
       'Sote-toiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017']
df.columns
# Out:
# Index(['Kunta', 'Taajama-aste, %, 2017', 'Väkiluku, 2017',
#        'Väkiluvun muutos edellisestä vuodesta, %, 2017',
#        'Alle 15-vuotiaiden osuus väestöstä, %, 2017',
#        '15-64 -vuotiaiden osuus väestöstä, %, 2017',
#        'Yli 64-vuotiaiden osuus väestöstä, %, 2017',
#        'Ruotsinkielisten osuus väestöstä, %, 2017',
#        'Ulkomaan kansalaisten osuus väestöstä, %, 2017',
#        'Syntyneiden enemmyys, henkilöä, 2017',
#        'Kuntien välinen muuttovoitto/-tappio, henkilöä, 2017',
#        'Perheiden lukumäärä, 2017', 'Asuntokuntien lukumäärä, 2017',
#        'Rivi- ja pientaloissa asuvien asuntokuntien osuus, %, 2017',
#        'Vuokra-asunnoissa asuvien asuntokuntien osuus, %, 2017',
#        'Vähintään toisen asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
#        'Korkea-asteen tutkinnon suorittaneiden osuus 15 vuotta täyttäneistä, %, 2017',
#        'Alueella asuvan työllisen työvoiman määrä, 2016',
#        'Työllisyysaste, %, 2016',
#        'Asuinkunnassaan työssäkäyvien osuus, %, 2016',
#        'Työttömien osuus työvoimasta, %, 2016',
#        'Eläkeläisten osuus väestöstä, %, 2016',
#        'Taloudellinen huoltosuhde, 2016',
#        'Alueella olevien työpaikkojen lukumäärä, 2016',
#        'Alkutuotannon työpaikkojen osuus, %, 2016',
#        'Jalostuksen työpaikkojen osuus, %, 2016',
#        'Palvelujen työpaikkojen osuus, %, 2016',
#        'Vuosikate, euroa/asukas, 2017', 'Lainakanta, euroa/asukas, 2017',
#        'Konsernin lainakanta, euroa/asukas, 2017',
#        'Opetus- ja kulttuuritoiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017',
#        'Sote-toiminta yhteensä, nettokäyttökustannukset, euroa/asukas, 2017'],
#       dtype='object')

# %%
df[['Kunta','Alkutuotannon työpaikkojen osuus, %, 2016','Jalostuksen työpaikkojen osuus, %, 2016','Palvelujen työpaikkojen osuus, %, 2016']].sort_values(by='Alkutuotannon työpaikkojen osuus, %, 2016', ascending=False).head(10)
# Out:
#           Kunta  Alkutuotannon työpaikkojen osuus, %, 2016  \
# 136  Lestijärvi                                       43.3
# 242   Savukoski                                       42.4
# 303       Vårdö                                       38.2
# 257    Sottunga                                       35.7
# 22       Halsua                                       30.1
# 36    Honkajoki                                       29.1
# 76     Karijoki                                       28.4
# 64    Jämijärvi                                       28.3
# 220  Rantasalmi                                       28.0
# 233    Rääkkylä                                       27.3
#
#      Jalostuksen työpaikkojen osuus, %, 2016  \
# 136                                     14.2
# 242                                      3.3
# 303                                     14.6
# 257                                      7.1
# 22                                      22.7
# 36                                      26.3
# 76                                      27.0
# 64                                      24.3
# 220                                     18.4
# 233                                     13.3
#
#      Palvelujen työpaikkojen osuus, %, 2016
# 136                                    40.5
# 242                                    53.0
# 303                                    39.0
# 257                                    57.1
# 22                                     45.0
# 36                                     42.5
# 76                                     42.7
# 64                                     44.3
# 220                                    52.1
# 233                                    56.1

# %%
df[['Kunta','Alkutuotannon työpaikkojen osuus, %, 2016','Jalostuksen työpaikkojen osuus, %, 2016','Palvelujen työpaikkojen osuus, %, 2016']].sort_values(by='Palvelujen työpaikkojen osuus, %, 2016', ascending=False).head(10)
# Out:
#              Kunta  Alkutuotannon työpaikkojen osuus, %, 2016  \
# 83      Kauniainen                                        0.5
# 160         Muonio                                        2.3
# 151  Maarianhamina                                        0.2
# 33        Helsinki                                        0.1
# 50           Inari                                        6.4
# 189  Pelkosenniemi                                        4.9
# 229      Rovaniemi                                        2.2
# 11           Espoo                                        0.1
# 276          Turku                                        0.4
# 102         Kolari                                        4.1
#
#      Jalostuksen työpaikkojen osuus, %, 2016  \
# 83                                       3.1
# 160                                      6.6
# 151                                      9.0
# 33                                      10.1
# 50                                       6.7
# 189                                      9.7
# 229                                     13.0
# 11                                      15.8
# 276                                     16.2
# 102                                      9.5
#
#      Palvelujen työpaikkojen osuus, %, 2016
# 83                                     93.4
# 160                                    89.4
# 151                                    88.9
# 33                                     88.9
# 50                                     84.7
# 189                                    84.4
# 229                                    83.5
# 11                                     82.9
# 276                                    82.4
# 102                                    82.1

# %%
df[['Kunta','Työllisyysaste, %, 2016','Eläkeläisten osuus väestöstä, %, 2016','Ruotsinkielisten osuus väestöstä, %, 2017','Taloudellinen huoltosuhde, 2016']][df['Taloudellinen huoltosuhde, 2016']<100]
# Out:
#         Kunta  Työllisyysaste, %, 2016  Eläkeläisten osuus väestöstä, %, 2016  \
# 57     Jomala                     87.5                                   15.8
# 133   Lemland                     84.3                                   18.2
# 257  Sottunga                     89.5                                   37.5
# 259      Sund                     86.3                                   25.2
#
#      Ruotsinkielisten osuus väestöstä, %, 2017  \
# 57                                        89.1
# 133                                       92.1
# 257                                       93.5
# 259                                       88.8
#
#      Taloudellinen huoltosuhde, 2016
# 57                              86.8
# 133                             96.5
# 257                             84.6
# 259                             97.6
